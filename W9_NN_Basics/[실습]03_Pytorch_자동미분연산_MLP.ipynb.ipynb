# %% [markdown]
# # Pytorch Tutoral - Autograd & MLP(Multi-layer perceptron)

# %% [markdown]
# # Autograd
#
# - `autograd`패키지는 텐서의 모든 연산에 대한 자동 미분을 제공
# - 실행-기반-정의(define-by-run) 프레임워크로, 코드를 어떻게 작성하여 실행하느냐에 따라 역전파가 정의된다는 것을 의미
# - 역전파는 학습 과정의 매 단계마다 달라짐

# %% [markdown]
# ## Tensor
#
# - `torch.Tensor` 클래스의 `.requires_grad` 속성을 `True`로 설정하면, 해당 텐서에서 이루어진 모든 연산을 추적(track)하기 시작
# - 계산이 완료된 후 `.backward()`를 호출하여 모든 변화도(gradient)를 자동으로 계산할 수 있으며 이 Tensor의 변화도는 `.grad` 속성에 누적됨
# - Tensor가 기록을 추적하는 것을 중단하게 하려면, `.detach()`를 호출하여 연산기록으로부터 분리하여 연산이 추적되는 것을 방지할 수 있음
# - 기록을 추적하는 것(과 메모리를 사용하는 것)을 방지하기 위해서 코드 블럭을 `with torch.no_grad():`로 감쌀 수 있음
# - 이는 변화도(gradient)는 필요 없지만 `requires_grad=True`가 설정되어 학습 가능한 매개변수를 갖는 모델을 평가(evaluate)할 때 유용
# - Autograd 구현에서 `Function` 클래스는 매우 중요한 역할을 수행
# - `Tensor`와 `Function`은 서로 연결되어 있고 모든 연산 과정을 부호화하여 순환하지 않는 그래프를 생성
# - 각 tensor는 `.grad_fn` 속성을 가지고 있는데 이는 `Tensor`를 생성한 `Function`을 참조함(단, 사용자가 만든 Tensor는 예외이며, 사용자가 만든 Tensor가 아닌 연산에 의해 생긴 텐서와 같은 경우는 모두 `Function`을 참조)
# - 도함수를 계산하기 위해서는 `Tensor`의 `.backward()`를 호출하면 됨

# %%
import torch

print(torch.__version__)
# Out:
# 1.9.0+cu102

# %%
# x의 연산 과적을 추적하기 위해 requires_grad=True로 설정
x = torch.ones(2, 2, requires_grad=True)
print(x)

# 직접 생선한 Tensor이기 때문에 grad_fn이 None인 것을 확인할 수 있음
print(x.grad_fn)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
# None

# %%
# y는 연산의 결과로 생성된 것이기 때문에 grad_fn을 갖고 있는 것을 확인 가능
y = x + 2
print(y)
# Out:
# tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)

# %%
# 연산의 결과로 생성된 것이기 때문에 grad_fn을 갖는 것을 확인 가능
print(y.grad_fn)
# Out:
# <AddBackward0 object at 0x7fa461f30910>

# %%
z = y * y * 3
out = z.mean()

# 각각 사용한 func에 맞게 grad_fn이 생성된 것을 확인할 수 있음
print(z)
print(out)
# Out:
# tensor([[27., 27.],
#         [27., 27.]], grad_fn=<MulBackward0>)
# tensor(27., grad_fn=<MeanBackward0>)

# %% [markdown]
# - `requires_grad_()`를 사용하면 기존 Tensor의 `requires_grad` 값을 바꿀 수 있음
# - 입력 값이 지정되지 않으면 기본 값은 `False`

# %%
a = torch.randn(2, 2)
print(a)
# Out:
# tensor([[ 0.4750,  0.1876],
#         [-0.3811,  0.8513]])

# %%
a = ((a * 3) / (a - 1))
print(a)
print(a.requires_grad)
# Out:
# tensor([[ -2.7142,  -0.6927],
#         [  0.8279, -17.1704]])
# False

# %%
a.requires_grad_(True)
# Out:
# tensor([[ -2.7142,  -0.6927],
#         [  0.8279, -17.1704]], requires_grad=True)

# %%
print(a.requires_grad)
# Out:
# True

# %%
b = (a * a).sum()
print(b)
print(b.requires_grad)
# Out:
# tensor(303.3547, grad_fn=<SumBackward0>)
# True

# %% [markdown]
# ## 변화도(Gradient)

# %%
print(out)

# 이전에 만든 out을 사용해서 역전파 진행

y.retain_grad()     # 중간 값에 대한 미분 값을 보고싶다면 해당 값에 대한 retain_grad()를 호출해야 함
z.retain_grad()
out.backward()      # 여러 번 미분을 진행하기 위해서는 retain_graph=True로 설정해줘야 함(그렇지 않으면 아래처럼 에러 발생)

# out.backward(torch.tensor(1.))을 진행하는 것과 동일
print(x.grad)
print(y.grad)
print(z.grad)
print(z.is_leaf)

out.backward()      # 에러 발생!
print(x.grad)
print(y.grad)
# Out:
# tensor(27., grad_fn=<MeanBackward0>)
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])
# tensor([[0.2500, 0.2500],
#         [0.2500, 0.2500]])
# False
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-e5106fca7c9d> in <module>()
#      13 print(z.is_leaf)
#      14
# ---> 15 out.backward()      # 에러 발생!
#      16 print(x.grad)
#      17 print(y.grad)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# RuntimeError: Trying to backward through the graph a second time (or directly access saved variables after they have already been freed). Saved intermediate values of the graph are freed when you call .backward() or autograd.grad(). Specify retain_graph=True if you need to backward through the graph a second time or if you need to access saved variables after calling backward.

# %%
x = torch.ones(2, 2, requires_grad=True)
y = x + 2
z = y * y * 3
out = z.mean()

print(out)

y.retain_grad()
out.backward(retain_graph=True)

print(x.grad)
print(y.grad)
print(z.grad)       # z.retain_grad()를 호출하지 않으면 grad값을 저장하지 않기 때문에 grad 속성을 볼 수 없음
print(z.is_leaf)

out.backward()      # 위에서 진행한 backward 말고도 추가로 backward 진행
print(x.grad)
print(y.grad)
# Out:
# tensor(27., grad_fn=<MeanBackward0>)
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])
# None
# False
# tensor([[9., 9.],
#         [9., 9.]])
# tensor([[9., 9.],
#         [9., 9.]])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   del sys.path[0]

# %%
# 이전에 만든 out을 사용해서 역전파 진행
# 여러번 역전파를 위해서는 retain_graph=True로 지정
out.backward(retain_graph=True)
# backward 진행 시 어떤 값에 대해서 진행하는 지 정해주지 않았을 때, default로 1이 들어감
# out.backward(torch.tensor[1.])을 진행하는 것과 동일

# %% [markdown]
# $$ out = \frac{1}{4} \sum_{i} z_i $$
# $$ z_i = 3(x_i + 2)^2 $$
# - `z_i`를 미분한 값에 적용하면 4.5를 동일하게 출력할 수 있음

# %% [markdown]
# $$ out(미분결과) = 1/4 * 6 * (x + 2) = {3 \over 2}(x+2) $$

# %% [markdown]
# ---

# %% [markdown]
# - 일반적으로 `torch.autograd`는 벡터-야코비안 곱을 계산하는 엔진
# - `torch.autograd`를 사용하면 전체 야코비안을 직접 계산할 수는 없지만, 벡터-야코비안 곱은 `backward`에 해당 벡터를 인자로 제공하여 얻을 수 있음

# %%
x = torch.randn(3, requires_grad=True)

y = x * 2

while y.data.norm() < 1000:
  y = y * 2

print(y)
# Out:
# tensor([-782.6967, -600.0043,  611.5406], grad_fn=<MulBackward0>)

# %%
# scalar값이 아닌 y의 벡터-야코비안 곱을 구하는 과정
v = torch.tensor([0.1, 1.0, 0.0001], dtype=torch.float)
y.backward(v)

print(x.grad)
# Out:
# tensor([2.0480e+02, 2.0480e+03, 2.0480e-01])

# %% [markdown]
# - `with torch.no_grad()`로 코드 블록을 감싸서 `autograd`가 `.requires_grad=True`인 Tensor의 연산 기록을 추적하는 것을 멈출 수도 있음

# %%
print(x.requires_grad)
print((x ** 2).requires_grad)

with torch.no_grad():
  print((x ** 2).requires_grad)
# Out:
# True
# True
# False

# %% [markdown]
# - 또는 `.detach()`를 호출하여 내용물은 같지만 `requires_grad`가 다른 새로운 텐서를 가져올 수 있음

# %%
print(x.requires_grad)
y = x.detach()
print(y.requires_grad)
print(x.eq(y).all())
# Out:
# True
# False
# tensor(True)

# %% [markdown]
# # ANN(Artificial Neural Networks)
#
# - 신경망은 `torch.nn` 패키지를 사용하여 생성할 수 있음
# - `nn`은 모델을 정의하고 미분하기 위해서 위에서 살펴본 `autograd`를 사용
# - `nn.Module`은 계층(layer)과 `output`을 반환하는 `forward(input)` 메소드를 포함

# %% [markdown]
# ---

# %% [markdown]
# - 간단한 순전파 네트워크(feed-forward-network)
# - 입력을 받아 여러 계층에 차례로 전달한 후, 최종 출력을 제공
# - 신경망의 일반적인 학습 과정
#
#
# > - 학습 가능한 매개변수(가중치)를 갖는 신경망을 정의
# > - 데이터 셋 입력을 반복
# > - 입력을 신경망에서 전파(process)
# > - 손실(loss; 입력 값과 예측 값과의 차이)를 계산
# > - 변화도(gradient)를 신경망의 매개변수들에 역으로 전파 - 역전파 과정
# > - 신경망의 가중치를 갱신
# > > - `새로운 가중치(weight) = 가중치(weight) - 학습률(learning rate) * 변화도(gradient)`

# %%
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()

        self.layer0 = nn.Linear(4, 128)
        self.layer1 = nn.Linear(128, 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 16)
        self.layer4 = nn.Linear(16, 3)

        self.bn0 = nn.BatchNorm1d(128)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(32)

        self.act = nn.ReLU()

    def forward(self, x):
      x = self.act(self.bn0(self.layer0(x)))
      x = self.act(self.bn1(self.layer1(x)))
      x = self.act(self.bn2(self.layer2(x)))
      x = self.act(self.layer3(x))
      x = self.layer4(x)

      return x

# %% [markdown]
# ## 손실 함수(Loss Function)
#
# - 손실 함수는 (output, target)을 한 쌍으로 입력 받아, 출력이 정답으로부터 얼마나 떨어져있는지 추정하는 값을 계산

# %% [markdown]
# - `forward`함수만 정의하고 나면 `backward`함수는 `autograd`를 사용하여 자동으로 정의됨
# - 모델의 학습 가능한 매개 변수는 `net.parameters()`에 의해 변환됨

# %%
# 랜덤 값 생성
criterion = nn.CrossEntropyLoss()

# ex_X : 4개의 sample, 4개의 특징
# ex_y : 4개의 sample에 대한 클래스
ex_X, ex_y = torch.randn([4, 4]), torch.tensor([1, 0, 2, 0])

net = Net()
output = net(ex_X)
loss = criterion(output, ex_y)  # 오차 값 계산
print('loss: ', loss.item())
  
net.zero_grad()  # Gradient를 모두 0으로 만들어줌

print('layer0.bias.grad before backward')
print(net.layer4.bias.grad)

print(net.layer4.bias.is_leaf)

loss.backward()  # 역전파

print('layer0.bias.grad after backward')
print(net.layer4.bias.grad)

"""
이 부분에서 .retain_grad() 를 사용하지 않아도 되는 이유는 weight와 bias의 파라미터가 leaf 노드이기 때문이라고 합니다.
설명이 포함된 링크들을 아래에 첨부해두니 읽어보시면 좋을 것 같습니다 :)

어떤 경우가 leaf 노드 인지 - https://discuss.pytorch.org/t/leaf-variable-was-used-in-an-inplace-operation/308/20
왜 leaf 노드인 경우에는 retain_grad()를 하지 않아도 grad 값이 나오는지 - https://discuss.pytorch.org/t/what-is-the-purpose-of-is-leaf/87000/7
"""
# Out:
# loss:  1.0702673196792603
# layer0.bias.grad before backward
# None
# True
# layer0.bias.grad after backward
# tensor([-0.2089,  0.0724,  0.1365])
# '\n이 부분에서 .retain_grad() 를 사용하지 않아도 되는 이유는 weight와 bias의 파라미터가 leaf 노드이기 때문이라고 합니다.\n설명이 포함된 링크들을 아래에 첨부해두니 읽어보시면 좋을 것 같습니다 :)\n\n어떤 경우가 leaf 노드 인지 - https://discuss.pytorch.org/t/leaf-variable-was-used-in-an-inplace-operation/308/20\n왜 leaf 노드인 경우에는 retain_grad()를 하지 않아도 grad 값이 나오는지 - https://discuss.pytorch.org/t/what-is-the-purpose-of-is-leaf/87000/7\n'

# %%
params = list(net.parameters())
print(len(params))
print(params[0].size())  # layer0의 weight
# Out:
# 16
# torch.Size([128, 4])

# %% [markdown]
# ## 가중치 갱신
# - 가장 단순한 갱신 규칙은 확률적 경사하강법(SGD; Stochastic Gradient Descent)
# - `새로운 가중치(weight) = 가중치(weight) - 학습률(learning rate) * 변화도(gradient)`

# %%
# torch.optim 패키지에 다양한 갱신 규칙이 규현되어 있음

import torch.optim as optim

optimizer = optim.SGD(net.parameters(), lr=0.001)

optimizer.zero_grad()
output = net(ex_X)
loss = criterion(output, ex_y)
loss.backward()
optimizer.step()  # 업데이트 진행

# %% [markdown]
# ## MLP 모델

# %%
from sklearn.datasets import load_iris

dataset = load_iris()

data = dataset.data
label = dataset.target

print(dataset.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
print('shape of data: ', data.shape)
print('shape of label: ',label.shape)
# Out:
# shape of data:  (150, 4)
# shape of label:  (150,)

# %%
# 훈련과 테스트 데이터로 나누기
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.25)
print(len(X_train))
print(len(X_test))
# Out:
# 112
# 38

# %%
# DataLoader 생성
X_train = torch.from_numpy(X_train).float()
y_train = torch.from_numpy(y_train).long()

X_test = torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test).long()

train_set = TensorDataset(X_train, y_train)

train_loader = DataLoader(train_set, batch_size=4, shuffle=True)   # batch size(학습할 때 한 번에 몇 개씩 볼 지) 설정, shuffle 설정

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()

        self.layer0 = nn.Linear(4, 128)
        self.layer1 = nn.Linear(128, 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 16)
        self.layer4 = nn.Linear(16, 3)

        self.bn0 = nn.BatchNorm1d(128)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(32)

        self.act = nn.ReLU()

    def forward(self, x):
      x = self.act(self.bn0(self.layer0(x)))
      x = self.act(self.bn1(self.layer1(x)))
      x = self.act(self.bn2(self.layer2(x)))
      x = self.act(self.layer3(x))
      x = self.layer4(x)

      return x
      # return nn.Softmax(x)

# %%
net = Net()
print(net)
# Out:
# Net(
#   (layer0): Linear(in_features=4, out_features=128, bias=True)
#   (layer1): Linear(in_features=128, out_features=64, bias=True)
#   (layer2): Linear(in_features=64, out_features=32, bias=True)
#   (layer3): Linear(in_features=32, out_features=16, bias=True)
#   (layer4): Linear(in_features=16, out_features=3, bias=True)
#   (bn0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act): ReLU()
# )

# %%
optimizer = torch.optim.SGD(net.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
epochs = 200

# %%
print(len(train_loader), len(X_train))
# Out:
# 28 112

# %%
losses = list()
accuracies = list()

for epoch in range(epochs):
  epoch_loss = 0  
  epoch_accuracy = 0
  for X, y in train_loader:
  
    optimizer.zero_grad()        # gradient 0으로 초기화
    
    output = net(X)              # 예측

    loss = criterion(output, y)  # 오차 계산
    loss.backward()              # 역전파
    
    optimizer.step()             # 업데이트
    # output = [0.11, 0.5, 0.8]  --> 예측 클래스 값
    _, predicted = torch.max(output, dim=1)   # 예측의 결과를 바탕으로 클래스 설정
    accuracy = (predicted == y).sum().item()
    epoch_loss += loss.item()
    epoch_accuracy += accuracy
  

  epoch_loss /= len(train_loader)
  epoch_accuracy /= len(X_train)
  print("epoch :{}, \tloss :{}, \taccuracy :{}".format(str(epoch+1).zfill(3),round(epoch_loss,4), round(epoch_accuracy,4)))
  
  losses.append(epoch_loss)
  accuracies.append(epoch_accuracy)
# Out:
# epoch :001, 	loss :1.1535, 	accuracy :0.2768
# epoch :002, 	loss :1.127, 	accuracy :0.3839
# epoch :003, 	loss :1.1115, 	accuracy :0.3839
# epoch :004, 	loss :1.0978, 	accuracy :0.3839
# epoch :005, 	loss :1.0814, 	accuracy :0.4375
# epoch :006, 	loss :1.0492, 	accuracy :0.4821
# epoch :007, 	loss :1.0398, 	accuracy :0.5179
# epoch :008, 	loss :1.0224, 	accuracy :0.4911
# epoch :009, 	loss :1.0101, 	accuracy :0.4821
# epoch :010, 	loss :0.9949, 	accuracy :0.5268
# epoch :011, 	loss :0.9977, 	accuracy :0.4554
# epoch :012, 	loss :0.9829, 	accuracy :0.4911
# epoch :013, 	loss :0.9761, 	accuracy :0.5268
# epoch :014, 	loss :0.9701, 	accuracy :0.5
# epoch :015, 	loss :0.9535, 	accuracy :0.5268
# epoch :016, 	loss :0.9738, 	accuracy :0.4732
# epoch :017, 	loss :0.9711, 	accuracy :0.4732
# epoch :018, 	loss :0.9302, 	accuracy :0.5179
# epoch :019, 	loss :0.9124, 	accuracy :0.5804
# epoch :020, 	loss :0.8787, 	accuracy :0.5982
# epoch :021, 	loss :0.8948, 	accuracy :0.5446
# epoch :022, 	loss :0.9, 	accuracy :0.5714
# epoch :023, 	loss :0.8969, 	accuracy :0.625
# epoch :024, 	loss :0.8582, 	accuracy :0.6518
# epoch :025, 	loss :0.8886, 	accuracy :0.625
# epoch :026, 	loss :0.9024, 	accuracy :0.625
# epoch :027, 	loss :0.8408, 	accuracy :0.7321
# epoch :028, 	loss :0.8485, 	accuracy :0.7232
# epoch :029, 	loss :0.8666, 	accuracy :0.6518
# epoch :030, 	loss :0.9084, 	accuracy :0.6429
# epoch :031, 	loss :0.8668, 	accuracy :0.7054
# epoch :032, 	loss :0.7997, 	accuracy :0.7589
# epoch :033, 	loss :0.8111, 	accuracy :0.7054
# epoch :034, 	loss :0.8218, 	accuracy :0.7143
# epoch :035, 	loss :0.8063, 	accuracy :0.7054
# epoch :036, 	loss :0.8257, 	accuracy :0.7143
# epoch :037, 	loss :0.8416, 	accuracy :0.7411
# epoch :038, 	loss :0.8108, 	accuracy :0.7321
# epoch :039, 	loss :0.7655, 	accuracy :0.7857
# epoch :040, 	loss :0.7386, 	accuracy :0.8482
# epoch :041, 	loss :0.8017, 	accuracy :0.7589
# epoch :042, 	loss :0.7733, 	accuracy :0.7589
# epoch :043, 	loss :0.7853, 	accuracy :0.7589
# epoch :044, 	loss :0.7313, 	accuracy :0.7411
# epoch :045, 	loss :0.7413, 	accuracy :0.7768
# epoch :046, 	loss :0.7264, 	accuracy :0.7679
# epoch :047, 	loss :0.7156, 	accuracy :0.7857
# epoch :048, 	loss :0.7449, 	accuracy :0.7143
# epoch :049, 	loss :0.8063, 	accuracy :0.6964
# epoch :050, 	loss :0.721, 	accuracy :0.7411
# epoch :051, 	loss :0.7034, 	accuracy :0.7857
# epoch :052, 	loss :0.6798, 	accuracy :0.8125
# epoch :053, 	loss :0.6857, 	accuracy :0.8036
# epoch :054, 	loss :0.6429, 	accuracy :0.7768
# epoch :055, 	loss :0.7146, 	accuracy :0.7679
# epoch :056, 	loss :0.6325, 	accuracy :0.8214
# epoch :057, 	loss :0.6522, 	accuracy :0.7679
# epoch :058, 	loss :0.7165, 	accuracy :0.7679
# epoch :059, 	loss :0.6568, 	accuracy :0.8036
# epoch :060, 	loss :0.6845, 	accuracy :0.7768
# epoch :061, 	loss :0.753, 	accuracy :0.7232
# epoch :062, 	loss :0.7465, 	accuracy :0.6786
# epoch :063, 	loss :0.6174, 	accuracy :0.7946
# epoch :064, 	loss :0.6926, 	accuracy :0.75
# epoch :065, 	loss :0.6953, 	accuracy :0.6964
# epoch :066, 	loss :0.607, 	accuracy :0.8036
# epoch :067, 	loss :0.6839, 	accuracy :0.7232
# epoch :068, 	loss :0.6847, 	accuracy :0.7589
# epoch :069, 	loss :0.6364, 	accuracy :0.7679
# epoch :070, 	loss :0.6474, 	accuracy :0.75
# epoch :071, 	loss :0.6616, 	accuracy :0.7321
# epoch :072, 	loss :0.6677, 	accuracy :0.7679
# epoch :073, 	loss :0.6205, 	accuracy :0.7946
# epoch :074, 	loss :0.6708, 	accuracy :0.7589
# epoch :075, 	loss :0.631, 	accuracy :0.7768
# epoch :076, 	loss :0.5881, 	accuracy :0.75
# epoch :077, 	loss :0.6442, 	accuracy :0.7679
# epoch :078, 	loss :0.5852, 	accuracy :0.7679
# epoch :079, 	loss :0.6347, 	accuracy :0.7679
# epoch :080, 	loss :0.6589, 	accuracy :0.7411
# epoch :081, 	loss :0.5845, 	accuracy :0.7768
# epoch :082, 	loss :0.5742, 	accuracy :0.7768
# epoch :083, 	loss :0.5961, 	accuracy :0.7946
# epoch :084, 	loss :0.6005, 	accuracy :0.8214
# epoch :085, 	loss :0.6036, 	accuracy :0.7768
# epoch :086, 	loss :0.6302, 	accuracy :0.7946
# epoch :087, 	loss :0.6866, 	accuracy :0.7232
# epoch :088, 	loss :0.5847, 	accuracy :0.7679
# epoch :089, 	loss :0.637, 	accuracy :0.7411
# epoch :090, 	loss :0.6459, 	accuracy :0.7143
# epoch :091, 	loss :0.653, 	accuracy :0.75
# epoch :092, 	loss :0.5827, 	accuracy :0.7946
# epoch :093, 	loss :0.5222, 	accuracy :0.8661
# epoch :094, 	loss :0.6283, 	accuracy :0.7232
# epoch :095, 	loss :0.5624, 	accuracy :0.8304
# epoch :096, 	loss :0.5903, 	accuracy :0.75
# epoch :097, 	loss :0.5274, 	accuracy :0.8571
# epoch :098, 	loss :0.5772, 	accuracy :0.8036
# epoch :099, 	loss :0.549, 	accuracy :0.7768
# epoch :100, 	loss :0.6081, 	accuracy :0.7232
# epoch :101, 	loss :0.6116, 	accuracy :0.7411
# epoch :102, 	loss :0.5979, 	accuracy :0.7411
# epoch :103, 	loss :0.5659, 	accuracy :0.7411
# epoch :104, 	loss :0.5632, 	accuracy :0.8036
# epoch :105, 	loss :0.5422, 	accuracy :0.8304
# epoch :106, 	loss :0.6177, 	accuracy :0.7321
# epoch :107, 	loss :0.5088, 	accuracy :0.8214
# epoch :108, 	loss :0.5964, 	accuracy :0.7857
# epoch :109, 	loss :0.5893, 	accuracy :0.75
# epoch :110, 	loss :0.5922, 	accuracy :0.7857
# epoch :111, 	loss :0.5387, 	accuracy :0.8036
# epoch :112, 	loss :0.5511, 	accuracy :0.7857
# epoch :113, 	loss :0.5629, 	accuracy :0.8036
# epoch :114, 	loss :0.5482, 	accuracy :0.7857
# epoch :115, 	loss :0.4848, 	accuracy :0.8571
# epoch :116, 	loss :0.5022, 	accuracy :0.8393
# epoch :117, 	loss :0.5609, 	accuracy :0.7946
# epoch :118, 	loss :0.5777, 	accuracy :0.7857
# epoch :119, 	loss :0.5295, 	accuracy :0.8036
# epoch :120, 	loss :0.509, 	accuracy :0.8393
# epoch :121, 	loss :0.5238, 	accuracy :0.8393
# epoch :122, 	loss :0.5322, 	accuracy :0.8304
# epoch :123, 	loss :0.539, 	accuracy :0.8393
# epoch :124, 	loss :0.5727, 	accuracy :0.8304
# epoch :125, 	loss :0.5523, 	accuracy :0.75
# epoch :126, 	loss :0.5626, 	accuracy :0.8036
# epoch :127, 	loss :0.4695, 	accuracy :0.8661
# epoch :128, 	loss :0.4656, 	accuracy :0.8214
# epoch :129, 	loss :0.4998, 	accuracy :0.7946
# epoch :130, 	loss :0.4967, 	accuracy :0.7946
# epoch :131, 	loss :0.4896, 	accuracy :0.875
# epoch :132, 	loss :0.4958, 	accuracy :0.7768
# epoch :133, 	loss :0.5028, 	accuracy :0.8036
# epoch :134, 	loss :0.5525, 	accuracy :0.7857
# epoch :135, 	loss :0.6262, 	accuracy :0.75
# epoch :136, 	loss :0.5123, 	accuracy :0.8214
# epoch :137, 	loss :0.4617, 	accuracy :0.875
# epoch :138, 	loss :0.5445, 	accuracy :0.7768
# epoch :139, 	loss :0.6398, 	accuracy :0.7411
# epoch :140, 	loss :0.6191, 	accuracy :0.7589
# epoch :141, 	loss :0.5607, 	accuracy :0.7946
# epoch :142, 	loss :0.6069, 	accuracy :0.75
# epoch :143, 	loss :0.4712, 	accuracy :0.8661
# epoch :144, 	loss :0.5569, 	accuracy :0.8125
# epoch :145, 	loss :0.5628, 	accuracy :0.7857
# epoch :146, 	loss :0.4933, 	accuracy :0.8304
# epoch :147, 	loss :0.5941, 	accuracy :0.7589
# epoch :148, 	loss :0.5245, 	accuracy :0.8304
# epoch :149, 	loss :0.4769, 	accuracy :0.8482
# epoch :150, 	loss :0.4066, 	accuracy :0.8929
# epoch :151, 	loss :0.5349, 	accuracy :0.7589
# epoch :152, 	loss :0.5536, 	accuracy :0.8214
# epoch :153, 	loss :0.4603, 	accuracy :0.8214
# epoch :154, 	loss :0.4262, 	accuracy :0.8839
# epoch :155, 	loss :0.5105, 	accuracy :0.8214
# epoch :156, 	loss :0.5469, 	accuracy :0.8036
# epoch :157, 	loss :0.4761, 	accuracy :0.8214
# epoch :158, 	loss :0.5496, 	accuracy :0.8304
# epoch :159, 	loss :0.4602, 	accuracy :0.8839
# epoch :160, 	loss :0.4061, 	accuracy :0.9286
# epoch :161, 	loss :0.5317, 	accuracy :0.8214
# epoch :162, 	loss :0.5027, 	accuracy :0.8036
# epoch :163, 	loss :0.5342, 	accuracy :0.7946
# epoch :164, 	loss :0.5648, 	accuracy :0.7589
# epoch :165, 	loss :0.5102, 	accuracy :0.8214
# epoch :166, 	loss :0.4569, 	accuracy :0.8661
# epoch :167, 	loss :0.499, 	accuracy :0.8304
# epoch :168, 	loss :0.6201, 	accuracy :0.7321
# epoch :169, 	loss :0.4072, 	accuracy :0.8839
# epoch :170, 	loss :0.516, 	accuracy :0.8393
# epoch :171, 	loss :0.4653, 	accuracy :0.8393
# epoch :172, 	loss :0.5186, 	accuracy :0.8036
# epoch :173, 	loss :0.4684, 	accuracy :0.8036
# epoch :174, 	loss :0.4912, 	accuracy :0.8571
# epoch :175, 	loss :0.5388, 	accuracy :0.8214
# epoch :176, 	loss :0.4637, 	accuracy :0.8571
# epoch :177, 	loss :0.4712, 	accuracy :0.8661
# epoch :178, 	loss :0.4536, 	accuracy :0.8839
# epoch :179, 	loss :0.4925, 	accuracy :0.8482
# epoch :180, 	loss :0.5381, 	accuracy :0.8125
# epoch :181, 	loss :0.5191, 	accuracy :0.8214
# epoch :182, 	loss :0.5237, 	accuracy :0.8125
# epoch :183, 	loss :0.4847, 	accuracy :0.8482
# epoch :184, 	loss :0.5598, 	accuracy :0.75
# epoch :185, 	loss :0.4775, 	accuracy :0.8036
# epoch :186, 	loss :0.413, 	accuracy :0.8839
# epoch :187, 	loss :0.4492, 	accuracy :0.875
# epoch :188, 	loss :0.4911, 	accuracy :0.8036
# epoch :189, 	loss :0.4513, 	accuracy :0.8214
# epoch :190, 	loss :0.4208, 	accuracy :0.875
# epoch :191, 	loss :0.4681, 	accuracy :0.8304
# epoch :192, 	loss :0.4065, 	accuracy :0.8839
# epoch :193, 	loss :0.4786, 	accuracy :0.8482
# epoch :194, 	loss :0.4203, 	accuracy :0.8393
# epoch :195, 	loss :0.4088, 	accuracy :0.9018
# epoch :196, 	loss :0.505, 	accuracy :0.8214
# epoch :197, 	loss :0.4691, 	accuracy :0.8482
# epoch :198, 	loss :0.3986, 	accuracy :0.8661
# epoch :199, 	loss :0.5257, 	accuracy :0.7946
# epoch :200, 	loss :0.472, 	accuracy :0.8393

# %%
# Plot result

import matplotlib.pyplot as plt

plt.figure(figsize=(20,5))
plt.subplots_adjust(wspace=0.2)

plt.subplot(1,2,1)
plt.title("$loss$",fontsize = 18)
plt.plot(losses)
plt.grid()
plt.xlabel("$epochs$", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)


plt.subplot(1,2,2)
plt.title("$accuracy$", fontsize = 18)
plt.plot(accuracies)
plt.grid()
plt.xlabel("$epochs$", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)

plt.show()

# %%
# Test

output = net(X_test)
print(torch.max(output, dim=1))
_, predicted = torch.max(output, dim=1)
accuracy = round((predicted == y_test).sum().item() / len(y_test),4)


print("test_set accuracy :", round(accuracy,4))
# Out:
# torch.return_types.max(
# values=tensor([1.6682, 0.6891, 0.8833, 2.9686, 1.7750, 2.9542, 0.8691, 1.6671, 2.4327,
#         1.7080, 0.8760, 0.7136, 3.3175, 0.9518, 3.0222, 2.3680, 0.9179, 4.5130,
#         0.7800, 1.9952, 0.8394, 2.3834, 4.1294, 0.7810, 0.9587, 0.6098, 1.9680,
#         0.6914, 2.9396, 1.3292, 0.6200, 0.9606, 0.5887, 2.5139, 3.3051, 1.3705,
#         0.7340, 1.9061], grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 0, 2, 2, 1, 0, 0, 0, 1, 1, 0, 1, 0, 0, 2, 2, 1, 0, 1, 2, 2, 1,
#         1, 1, 0, 0, 2, 0, 1, 0, 1, 2, 2, 2, 1, 0]))
# test_set accuracy : 0.9211
