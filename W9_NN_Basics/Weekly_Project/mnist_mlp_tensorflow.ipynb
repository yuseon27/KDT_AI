# %% [markdown]
# # #4. 3번의 PyTorch로 구현된 모델을 TensorFlow로 동일하게 구현
#
# ### 모델의 구조 : 784 -> 512 -> 256 -> 128 -> 10

# %% [markdown]
# ### Import Tensorflow and other libraries

# %%
# import libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import os
import numpy as np
import matplotlib.pyplot as plt

try:
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

keras = tf.keras

print("tensorflow version",tf.__version__)
# Out:
# tensorflow version 2.5.0

# %% [markdown]
# ### Load MNIST Data and Define parameters

# %%
# Load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("Train data 개수:",len(x_train))
print("Test data 개수:",len(x_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Train data 개수: 60000
# Test data 개수: 10000

# %%
# Specify parameters
input_shape  = [28, 28]
num_classes  = 10

LEARNING_RATE = 0.1
EPOCHS = 10
BATCH_SIZE = 20

# %% [markdown]
# ## Sequential Model

# %% [markdown]
# ### Define Sequential Model

# %%
model = tf.keras.models.Sequential()
model.add(layers.InputLayer(input_shape))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 567,434
# Trainable params: 567,434
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define Optimizer

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE)

# %% [markdown]
# ### Train Sequential Model

# %%
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE
                    )
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - 9s 2ms/step - loss: 0.2219 - accuracy: 0.9320
# Epoch 2/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0892 - accuracy: 0.9723
# Epoch 3/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0603 - accuracy: 0.9812
# Epoch 4/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0411 - accuracy: 0.9868
# Epoch 5/10
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0314 - accuracy: 0.9901
# Epoch 6/10
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0250 - accuracy: 0.9920
# Epoch 7/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0189 - accuracy: 0.9937
# Epoch 8/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0139 - accuracy: 0.9952
# Epoch 9/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0134 - accuracy: 0.9956
# Epoch 10/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0074 - accuracy: 0.9979

# %% [markdown]
# ### Test Sequential Model

# %%
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print("테스트 성능 : Test Loss : {}, Test Accuracy :{}%".format(round(loss_and_metrics[0],6),
                               round(loss_and_metrics[1]*100,4)))
# Out:
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0749 - accuracy: 0.9821
# 테스트 성능 : Test Loss : 0.074917, Test Accuracy :98.21%

# %% [markdown]
# ## Functional Model

# %% [markdown]
# ### Define Functional Model

# %%
def deeper_net(input_shape, num_classes) : #{

    input_layer = layers.Input(input_shape)
    x = layers.Flatten()(input_layer)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dense(128, activation='relu')(x)
    output_layer = layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(input_layer, output_layer)
    return model
#}

deeper_model = deeper_net(input_shape, num_classes)
deeper_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 567,434
# Trainable params: 567,434
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train Functional model

# %%
deeper_model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = deeper_model.fit(x_train, y_train,
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE
                    )
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.2189 - accuracy: 0.9321
# Epoch 2/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0893 - accuracy: 0.9725
# Epoch 3/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0590 - accuracy: 0.9814
# Epoch 4/10
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0414 - accuracy: 0.9869
# Epoch 5/10
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0319 - accuracy: 0.9897
# Epoch 6/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0250 - accuracy: 0.9917
# Epoch 7/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0183 - accuracy: 0.9941
# Epoch 8/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0135 - accuracy: 0.9957
# Epoch 9/10
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.0079 - accuracy: 0.9979
# Epoch 10/10
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0097 - accuracy: 0.9970

# %% [markdown]
# ### Test Functional Model

# %%
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print("테스트 성능 : Test Loss : {}, Test Accuracy :{}%".format(round(loss_and_metrics[0],6),
                               round(loss_and_metrics[1]*100,4)))
# Out:
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0749 - accuracy: 0.9821
# 테스트 성능 : Test Loss : 0.074917, Test Accuracy :98.21%
